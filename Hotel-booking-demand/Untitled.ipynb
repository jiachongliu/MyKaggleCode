# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

data_train = pd.read_csv("hotel_bookings.csv")
data_train
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data_train.head(20)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
data_train["lead_time"].describe()
# Out:
# count    119390.000000
# mean        104.011416
# std         106.863097
# min           0.000000
# 25%          18.000000
# 50%          69.000000
# 75%         160.000000
# max         737.000000
# Name: lead_time, dtype: float64

# %%
sns.distplot(data_train["lead_time"])

# %%
plt.hist(data_train["is_canceled"], bins=2, range=(0, 1))
# Out:
# (array([75166., 44224.]), array([0. , 0.5, 1. ]), <a list of 2 Patch objects>)
